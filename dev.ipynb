# %%
import numpy as np
import matplotlib.pyplot as plt
rollouts = np.load('data/canonical/rollouts.npz')

# %%
rollouts["length"].mean()
l = rollouts['length']
plt.hist(l[l<200], bins=20)
plt.show()
